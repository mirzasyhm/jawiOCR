# %%
# 1. Mount your Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content
# !rm -r jawiOCR
# !git clone https://github.com/mirzasyhm/jawiOCR.git
# %cd /content/jawiOCR/jord/
# Out:
# /content
# rm: cannot remove 'jawiOCR': No such file or directory
# Cloning into 'jawiOCR'...
# remote: Enumerating objects: 458, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 458 (delta 45), reused 56 (delta 22), pack-reused 378 (from 1)
# Receiving objects: 100% (458/458), 101.53 MiB | 65.88 MiB/s, done.
# Resolving deltas: 100% (166/166), done.
# /content/jawiOCR/jord

# %%
# !wget https://huggingface.co/datasets/mirzasyhm/synthetic_jawi_images/resolve/main/jawi_orientation_dataset.tar -O jawi.tar

# !tar -xf jawi.tar
# Out:
# --2025-05-30 00:11:52--  https://huggingface.co/datasets/mirzasyhm/synthetic_jawi_images/resolve/main/jawi_orientation_dataset.tar
# Resolving huggingface.co (huggingface.co)... 18.164.174.17, 18.164.174.55, 18.164.174.118, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.17|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !pip install pip-tools
# !pip install -r requirements.txt

# %%
# !python train.py
# Out:
# 2025-05-30 00:16:09.284562: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-30 00:16:09.302253: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748564169.323273    3817 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748564169.329677    3817 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from google.colab import drive
local_path = 'best_jawi_orientation_resnet50.keras'               # path to the file in Colab VM
drive_path = '/content/drive/MyDrive/'  # target path in your Drive

# 3. Copy the file into Drive
import shutil
shutil.copy(local_path, drive_path)

print(f"Saved {local_path} to {drive_path}")
# Out:
# Saved best_jawi_orientation_resnet50.keras to /content/drive/MyDrive/

# %%
from google.colab import drive
local_path = 'training_history_resnet50.png'               # path to the file in Colab VM
drive_path = '/content/drive/MyDrive/'  # target path in your Drive

# 3. Copy the file into Drive
import shutil
shutil.copy(local_path, drive_path)

print(f"Saved {local_path} to {drive_path}")
# Out:
# Saved training_history_resnet50.png to /content/drive/MyDrive/

# %%
from google.colab import files
files.download('best_jawi_orientation_resnet50.keras')

# %%
# !python demo.py ./demo/0_1.jpg ./demo/0_2.jpg ./demo/0_3.jpg ./demo/90_1.jpg ./demo/90_2.jpg ./demo/90_3.jpg ./demo/180_1.jpg ./demo/180_2.jpg ./demo/180_3.jpg ./demo/270_1.jpg ./demo/270_2.jpg ./demo/270_3.jpg ./demo/demo_1.jpg ./demo/demo_2.jpg ./demo/demo_3.jpg ./demo/demo_4.jpg ./demo/demo_5.jpg ./demo/demo_6.jpg ./demo/demo_7.jpg
# Out:
# 2025-06-01 11:37:18.370105: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748777838.388364   26656 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748777838.393801   26656 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-01 11:37:18.412051: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
from IPython.display import Image, display# Display image from Google Drive
display(Image('./predictions_v2/demo_6_rotated_45deg_expanded.png'))

# %%
# !ls demo/demo_1.jpg
# Out:
# demo_1.jpg  demo_2.jpg	demo_3.jpg  demo_4.jpg

# %%
# !wget "https://huggingface.co/datasets/mirzasyhm/checkpoint_jawi/resolve/main/best_jawi_orientation_resnet50.keras"
# Out:
# --2025-06-01 10:44:46--  https://huggingface.co/datasets/mirzasyhm/checkpoint_jawi/resolve/main/best_jawi_orientation_resnet50.keras
# Resolving huggingface.co (huggingface.co)... 3.166.152.105, 3.166.152.44, 3.166.152.110, ...
# Connecting to huggingface.co (huggingface.co)|3.166.152.105|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !ls
# Out:
# best_jawi_orientation_resnet50.keras  jawi_orientation_resnet50.keras
# cnn.py				      jawi.tar
# data_preprocessing.py		      __pycache__
# demo				      requirements.txt
# demo.py				      training_history_resnet50.png
# jawi_orientation_dataset	      train.py

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 344 bytes | 344.00 KiB/s, done.
# From https://github.com/mirzasyhm/jawiOCR
#    c2f9a05..9e10c33  main       -> origin/main
# Updating c2f9a05..9e10c33
# Fast-forward
#  jord/demo.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)
