# %%
# %cd /content
# !rm -r jawiOCR
# !git clone https://github.com/mirzasyhm/jawiOCR.git
# %cd /content/jawiOCR/crnn/
# Out:
# /content
# rm: cannot remove 'jawiOCR': No such file or directory
# Cloning into 'jawiOCR'...
# remote: Enumerating objects: 583, done.
# remote: Counting objects: 100% (205/205), done.
# remote: Compressing objects: 100% (155/155), done.
# remote: Total 583 (delta 111), reused 139 (delta 48), pack-reused 378 (from 1)
# Receiving objects: 100% (583/583), 102.63 MiB | 15.24 MiB/s, done.
# Resolving deltas: 100% (232/232), done.
# /content/jawiOCR/crnn

# %%
# !pip install pip-tools
# !pip install -r requirements.txt
# Out:
# Collecting pip-tools
#   Downloading pip_tools-7.4.1-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: build>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from pip-tools) (1.2.2.post1)
# Requirement already satisfied: click>=8 in /usr/local/lib/python3.11/dist-packages (from pip-tools) (8.2.1)
# Requirement already satisfied: pip>=22.2 in /usr/local/lib/python3.11/dist-packages (from pip-tools) (24.1.2)
# Requirement already satisfied: pyproject-hooks in /usr/local/lib/python3.11/dist-packages (from pip-tools) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from pip-tools) (75.2.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from pip-tools) (0.45.1)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.11/dist-packages (from build>=1.0.0->pip-tools) (24.2)
# Downloading pip_tools-7.4.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: pip-tools
# Successfully installed pip-tools-7.4.1
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (0.21.0+cu124)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (11.2.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (4.67.1)
# Collecting lmdb (from -r requirements.txt (line 5))
#   Downloading lmdb-1.6.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (4.11.0.86)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (0.31.4)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (0.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 1)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 1)) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 1)) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->-r requirements.txt (line 1))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->-r requirements.txt (line 1))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->-r requirements.txt (line 1))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->-r requirements.txt (line 1))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->-r requirements.txt (line 1))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->-r requirements.txt (line 1))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->-r requirements.txt (line 1))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->-r requirements.txt (line 1))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->-r requirements.txt (line 1))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 1)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 1)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 1)) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->-r requirements.txt (line 1))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 1)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->-r requirements.txt (line 1)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->-r requirements.txt (line 7)) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->-r requirements.txt (line 7)) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->-r requirements.txt (line 7)) (2.32.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->-r requirements.txt (line 1)) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->-r requirements.txt (line 7)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->-r requirements.txt (line 7)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->-r requirements.txt (line 7)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->-r requirements.txt (line 7)) (2025.4.26)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 66.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 69.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 108.8 MB/s eta 0:00:00
# Downloading lmdb-1.6.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.8/297.8 kB 27.6 MB/s eta 0:00:00
# Installing collected packages: lmdb, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed lmdb-1.6.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# !python download_dataset.py
# Out:
# Downloading dataset from https://huggingface.co/datasets/mirzasyhm/synthetic_jawi_images/resolve/main/data_jawi_color_2_lmdb.tar...
# Extracting data_jawi_color_2_lmdb.tar into ./content/ ...
# Dataset extracted. Expected at: ./content/data_jawi_color_2_lmdb

# %%
# !python dataset.py

# %%
# !python build_alphabet.py
# Out:
# --- Building Jawi Character Alphabet ---
# Building alphabet from LMDB dataset at: content/data_jawi_color_2_lmdb/train
# Scanning 144000 samples to build alphabet...
# Scanning labels: 100% 144000/144000 [00:00<00:00, 412489.97it/s]
#
# Alphabet built successfully.
# Found 46 unique Jawi characters.
# Total number of classes (including CTC blank): 47
# Alphabet saved to 'alphabet.json'
#
# Script finished. The alphabet can now be loaded from 'alphabet.json'.

# %%
# !python train.py #if you want to train
# Out:
# Using device: cuda
# Alphabet loaded: 46 characters, 47 classes (incl. blank).
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:624: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# DataLoaders created. Train batches: 2250, Val batches: 282
# Model, Criterion, Optimizer, Scaler, Scheduler initialized.
#
# --- Starting Training for 3 epochs ---
# Epoch 1/3 [Train]: 100% 2250/2250 [02:49<00:00, 13.31it/s, loss=2]
# Epoch 1/3 - Train Loss: 2.8440
# Epoch 1/3 [Validate]: 100% 282/282 [00:17<00:00, 16.15it/s, val_loss=2.14]
# Epoch 1/3 - Val Loss: 2.0148, Val CER: 0.5725
# → New best CER: 0.5725, checkpoint saved.
# Epoch 2/3 [Train]: 100% 2250/2250 [02:45<00:00, 13.61it/s, loss=0.396]
# Epoch 2/3 - Train Loss: 1.1293
# Epoch 2/3 [Validate]: 100% 282/282 [00:17<00:00, 16.01it/s, val_loss=0.474]
# Epoch 2/3 - Val Loss: 0.5197, Val CER: 0.1472
# → New best CER: 0.1472, checkpoint saved.
# Epoch 3/3 [Train]: 100% 2250/2250 [02:45<00:00, 13.57it/s, loss=0.183]
# Epoch 3/3 - Train Loss: 0.3509
# Epoch 3/3 [Validate]: 100% 282/282 [00:17<00:00, 15.99it/s, val_loss=0.397]
# Epoch 3/3 - Val Loss: 0.3013, Val CER: 0.0882
# → New best CER: 0.0882, checkpoint saved.
#
# --- Training Finished ---
# Best Validation CER achieved: 0.0882

# %%
import os

# Create a folder to unzip into
os.makedirs("outputs", exist_ok=True)

# Download
# !wget -O checkpoints.zip https://huggingface.co/datasets/mirzasyhm/checkpoint_jawi/resolve/main/checkpoints_color.zip

# Unzip into that folder
# !unzip -q checkpoints.zip -d checkpoints

# Clean up
# !rm checkpoints.zip
# Out:
# --2025-06-01 16:57:54--  https://huggingface.co/datasets/mirzasyhm/checkpoint_jawi/resolve/main/checkpoints_color.zip
# Resolving huggingface.co (huggingface.co)... 13.35.202.34, 13.35.202.121, 13.35.202.40, ...
# Connecting to huggingface.co (huggingface.co)|13.35.202.34|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs-us-1.hf.co/repos/a4/0e/a40edb5fee9aa56b081d76cebeb85749da8b1935a5194f415623e5924b1f8594/acabb8c59097af417044adf88e4f832aebb6a05f62c98f55a444db282d387cd4?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27checkpoints_color.zip%3B+filename%3D%22checkpoints_color.zip%22%3B&response-content-type=application%2Fzip&Expires=1748800674&Policy=...&Signature=iavEzxlgKeNVJelt32DhTm4XaPG21lWVm4U4efywxAH7xlcDJkZNBfESUPP4qsWV-yru5gsIyY3BDprZFZZb2ZrEWHKpOPi3pGtRfw98zoBhedsrPRZ6ECyKdo%7E7uzlTfJUeAMvLptZdDYcaCUmsAl6ElO9wpBM1eWeRaLIcN-qvqSeNN39b7lgXN2GHOzpcnkYTBQh7KktTYFnq727t0XJxOkMpT452-u-QUgflKMIjWDfcj3oOgvzdqpMD-f7EHz4%7EJsNdDlDIUXAy9WMuqieG%7EHw2DQjXISMcKfcjcMjssrQakZJ1tkbZYFta%7EqqJxPmSPcRy2WIf2x-UbpXhqw__&Key-Pair-Id=K24J24Z295AEI9 [following]
# --2025-06-01 16:57:54--  https://cdn-lfs-us-1.hf.co/repos/a4/0e/a40edb5fee9aa56b081d76cebeb85749da8b1935a5194f415623e5924b1f8594/acabb8c59097af417044adf88e4f832aebb6a05f62c98f55a444db282d387cd4?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27checkpoints_color.zip%3B+filename%3D%22checkpoints_color.zip%22%3B&response-content-type=application%2Fzip&Expires=1748800674&Policy=...&Signature=iavEzxlgKeNVJelt32DhTm4XaPG21lWVm4U4efywxAH7xlcDJkZNBfESUPP4qsWV-yru5gsIyY3BDprZFZZb2ZrEWHKpOPi3pGtRfw98zoBhedsrPRZ6ECyKdo%7E7uzlTfJUeAMvLptZdDYcaCUmsAl6ElO9wpBM1eWeRaLIcN-qvqSeNN39b7lgXN2GHOzpcnkYTBQh7KktTYFnq727t0XJxOkMpT452-u-QUgflKMIjWDfcj3oOgvzdqpMD-f7EHz4%7EJsNdDlDIUXAy9WMuqieG%7EHw2DQjXISMcKfcjcMjssrQakZJ1tkbZYFta%7EqqJxPmSPcRy2WIf2x-UbpXhqw__&Key-Pair-Id=K24J24Z295AEI9
# Resolving cdn-lfs-us-1.hf.co (cdn-lfs-us-1.hf.co)... 3.171.198.59, 3.171.198.97, 3.171.198.15, ...
# Connecting to cdn-lfs-us-1.hf.co (cdn-lfs-us-1.hf.co)|3.171.198.59|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30970120 (30M) [application/zip]
# Saving to: ‘checkpoints.zip’
#
# checkpoints.zip     100%[===================>]  29.54M  26.2MB/s    in 1.1s
#
# 2025-06-01 16:57:55 (26.2 MB/s) - ‘checkpoints.zip’ saved [30970120/30970120]

# %%
# !python evaluation.py
# Out:
# Using device: cuda
# Alphabet loaded from 'alphabet.json': 46 characters, 47 classes.
# Loading model state_dict from 'checkpoints/best_crnn.pth'...
# Model initialized and state loaded. Set to evaluation mode.
# Test DataLoader created with 18000 samples in 282 batches.
#
# --- Starting Evaluation on Test Set ---
# Evaluating on Test Set: 100% 282/282 [00:18<00:00, 14.96it/s]
#
# --- Evaluation Finished ---
#
# Total samples evaluated: 18000
# Test CER: 0.0885
# Test WER: 0.3784
#
# First 30 (GT → Pred):
#  1. 'ڤلنچر'                                             →  'ڤلنچر'
#  2. 'ڤلنچر'                                             →  'ڤلنچر'
#  3. 'ڤنواي'                                             →  'ڤنواي'
#  4. 'سدڠکل'                                             →  'سدڠکل'
#  5. 'تݢر'                                               →  'تݢر'
#  6. 'تݢر'                                               →  'تݢر'
#  7. 'ڤڽيݢيلن'                                           →  'ڤڽيݢيلن'
#  8. 'ليمبيڠ'                                            →  'ليمبيڠ'
#  9. 'ليمبيڠ'                                            →  'ليمبيڠ'
# 10. 'ليمبيڠ'                                            →  'ليمبيڠ'
# 11. 'دسامبت'                                            →  'دسامبت'
# 12. 'ݢامر'                                              →  'ݢامر'
# 13. 'برتيوڤ'                                            →  'برتيوڤ'
# 14. 'برتيوڤ'                                            →  'برتيوڤ'
# 15. 'برتيوڤ'                                            →  'برتيوڤ'
# 16. 'ݢامر'                                              →  'ݢامر'
# 17. 'تردوهوق'                                           →  'فردهوق'
# 18. 'خلق'                                               →  'خلق'
# 19. 'ترڤيهيت'                                           →  'ترڤيهيت'
# 20. 'ايريڠ-ايريڠن'                                      →  'ايڠ-ايڠن'
# 21. 'مڽجوقکنڽ'                                          →  'مڽجوقکنڽ'
# 22. 'برواجهکن'                                          →  'برواجهکن'
# 23. 'برواجهکن'                                          →  'برواجکن'
# 24. 'برواجهکن'                                          →  'برواهکن'
# 25. 'ساݢر'                                              →  'ساݢر'
# 26. 'ساݢر'                                              →  'ساݢر'
# 27. 'اونڠ-انيڠ'                                         →  'اونڠاليڠ'
# 28. 'اونڠ-انيڠ'                                         →  'اونڠ-ايڠ'
# 29. 'سيدنا'                                             →  'سيدنا'
# 30. 'دڤرليهتکنڽ'                                        →  'دڤرليهکنڽ'
